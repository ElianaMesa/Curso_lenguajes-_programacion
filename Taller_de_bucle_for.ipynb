# %% [markdown]
# <a href="https://colab.research.google.com/github/ElianaMesa/Curso_lenguajes-_programacion/blob/main/Taller_de_bucle_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INVERSIONES OKTU**
# ## **Registro de clientes**

# %%
#Lista de clientes
clientes = ["Juan Perez", "Maria Rodriguez", "Carlos Lopez", "Ana Gomez"]
montos_invertidos = [10000, 15000, 20000, 18000]
rendimientos = [5.5, 6.0, 4.0, 7.5]
print(clientes)
print(montos_invertidos)
print(rendimientos)
# Out:
# ['Juan Perez', 'Maria Rodriguez', 'Carlos Lopez', 'Ana Gomez']
# [10000, 15000, 20000, 18000]
# [5.5, 6.0, 4.0, 7.5]

# %% [markdown]
# ## **Tuplas**

# %%
Cliente_1 = ("Juan Perez", 10000, 5.5)
Cliente_1
# Out:
# ('Juan Perez', 10000, 5.5)

# %%
Cliente_2 = ("Maria Roguez", 15000, 6.0)
Cliente_2
# Out:
# ('Maria Roguez', 15000, 6.0)

# %%
Cliente_3 = ("Carlos Lopez", 20000, 4.0)
Cliente_3
# Out:
# ('Carlos Lopez', 20000, 4.0)

# %%
Cliente_4 = ("Ana Gomez", 18000, 7.5)
Cliente_4
# Out:
# ('Ana Gomez', 18000, 7.5)

# %% [markdown]
# ## **Diccionario**

# %%
Portafolio = {
    "Juan Perez": {"monto_invertido": 10000, "rendimiento": 5.5},
    "Maria Rodriguez": {"monto_invertido": 15000, "rendimiento": 6.0},
    "Carlos Lopez": {"monto_invertido": 25000, "rendimiento": 4.0},
    "Ana Rodriguez": {"monto_invertido": 18000, "rendimiento": 7.5}

}
print(type(Portafolio))
print(Portafolio)
# Out:
# <class 'dict'>
# {'Juan Perez': {'monto_invertido': 10000, 'rendimiento': 5.5}, 'Maria Rodriguez': {'monto_invertido': 15000, 'rendimiento': 6.0}, 'Carlos Lopez': {'monto_invertido': 25000, 'rendimiento': 4.0}, 'Ana Rodriguez': {'monto_invertido': 18000, 'rendimiento': 7.5}}

# %% [markdown]
# ## **Rendimiento de los clientes**

# %%
for cliente, datos in Portafolio.items():
  if datos ["rendimiento"] > 5.0:
    print(f"{cliente} tiene un rendimiento de {datos['rendimiento']}%")
# Out:
# Juan Perez tiene un rendimiento de 5.5%
# Maria Rodriguez tiene un rendimiento de 6.0%
# Ana Rodriguez tiene un rendimiento de 7.5%

# %% [markdown]
# ## **Cálculo de los rendimientos**

# %%
rendimiento_total = 0
for cliente, datos in Portafolio.items():
         rendimiento_cliente = (datos["monto_invertido"] *
                         datos["rendimiento"]) / 100
         rendimiento_total += rendimiento_cliente
         print(f"El rendimiento total del portafolio es: ${rendimiento_total:.2f}")
# Out:
# El rendimiento total del portafolio es: $550.00
# El rendimiento total del portafolio es: $1450.00
# El rendimiento total del portafolio es: $2250.00
# El rendimiento total del portafolio es: $3600.00

# %% [markdown]
# ## **Cliente con mayor rendimiento**

# %%
max_rendimiento = 0
cliente_mayor= None

for cliente, datos in Portafolio.items():
    rendimiento_cliente
    if rendimiento_total > max_rendimiento:
        max_rendimiento = rendimiento_cliente
        cliente_mayor = cliente

print(f"El cliente con mayor rendimiento en dólares es {cliente_mayor} con un rendimiento de: ${max_rendimiento:.2f}")
# Out:
# El cliente con mayor rendimiento en dólares es Ana Rodriguez con un rendimiento de: $1350.00

# %% [markdown]
# ## **Actualización inversión Carlos Lopez**

# %%
print(Portafolio)
# Out:
# {'Juan Perez': {'monto_invertido': 10000, 'rendimiento': 5.5}, 'Maria Rodriguez': {'monto_invertido': 15000, 'rendimiento': 6.0}, 'Carlos Lopez': {'monto_invertido': 25000, 'rendimiento': 4.0}, 'Ana Rodriguez': {'monto_invertido': 18000, 'rendimiento': 7.5}}

# %% [markdown]
# ## **Nuevo Cliente, "Laura Fernandez"**

# %%
Portafolio["Laura Fernanadez"] = {"monto_invertido": 22000, "rendimiento": 6.8}
print(Portafolio)
# Out:
# {'Juan Perez': {'monto_invertido': 10000, 'rendimiento': 5.5}, 'Maria Rodriguez': {'monto_invertido': 15000, 'rendimiento': 6.0}, 'Carlos Lopez': {'monto_invertido': 25000, 'rendimiento': 4.0}, 'Ana Rodriguez': {'monto_invertido': 18000, 'rendimiento': 7.5}, 'Laura Fernanadez': {'monto_invertido': 22000, 'rendimiento': 6.8}}

# %% [markdown]
# ## **Remover a "Ana Gomez"**

# %%
Portafolio.pop("Ana Rodriguez")
print(Portafolio)
# Out:
# {'Juan Perez': {'monto_invertido': 10000, 'rendimiento': 5.5}, 'Maria Rodriguez': {'monto_invertido': 15000, 'rendimiento': 6.0}, 'Carlos Lopez': {'monto_invertido': 25000, 'rendimiento': 4.0}, 'Laura Fernanadez': {'monto_invertido': 22000, 'rendimiento': 6.8}}
